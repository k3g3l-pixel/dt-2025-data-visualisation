# %% [markdown]
# Movie analysis

# %%
# !pip install pandas matplotlib numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
df=pd.read_csv("homework5data.csv")
df
# Out:
#                                          Movie_title       Genre  Year  \
# 0                     The Good, the Bad and the Ugly     Western  1966
# 1                                            Deadpool     Comedy  2016
# 2                            Guardians of the Galaxy      Sci-Fi  2014
# 3                                                Thor    Fantasy  2011
# 4                                       Transformers      Sci-Fi  2007
# 5   Pirates of the Caribbean: The Curse of the Bla...  Adventure  2003
# 6                                           Hercules     Musical  1997
# 7   The Lord of the Rings: The Fellowship of the Ring    Fantasy  2001
# 8                                      Thor: Ragnarok     Sci-Fi  2017
# 9                                            Aladdin     Musical  1992
# 10                                             Grease    Musical  1978
# 11         Pirates of the Caribbean: Dead Man's Chest  Adventure  2006
# ...

# %%
print(df.columns)
# Out:
# Index(['Movie_title ', 'Genre', 'Year', 'Rating ', 'Box_office ', 'Duration '], dtype='object')

# %%
#import matplotlib.pyplot as plt
#avg_duration=df.groupby("Movie_title")["Duratione"].mean()
#avg_duration.plot(kind="bar", x="Movie_title", y="Duration")
#plt.title("What movie has the longest duration?")

#plt.show



#import matplotlib.pyplot as plt
#avg_hours=df.groupby("Movie_title")["Duration"].mean()
#avg_hours.plot(kind="bar", x="Student", y="Hours_Studied")
#plt.title("Who puts in the most effort")
#plt.show()


import matplotlib.pyplot as plt
df.plot(kind="bar", x="Year", y="Duration")
#plt.ylabel("Years")
#plt=title("Years of practice per athlete")
plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 18
#       1 #import matplotlib.pyplot as plt
# ...

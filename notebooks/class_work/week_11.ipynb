# %%
number=3+5 #if numbers use "koma ," if not, its astring and use quotes around variable
print("The total is",+number)
# Out:
# The total is 8

# %%
name="Johanne"
print("Hello "+name)
# Out:
# Hello Johanne

# %%
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for letter in name:
    print(letter)
# Out:
# J
# o
# h
# a
# n
# n
# e

# %%
age=8
if age<=7:
    print("Can ride for free")
else:
    print("Must buy ticket")
# Out:
# Must buy ticket

# %%
age=27
if age<=7: print("Can ride for free")
else: print("Must buy ticket")
if age<27:print("Child ticket")
else:print("Adult ticket")
# Out:
# Must buy ticket
# Adult ticket

# %%
sentence="racecarlevelfield"
print(sentence[0:3])
# Out:
# rac

# %%
sentence="racecarlevelfield"
print(sentence[:3])
# Out:
# rac

# %%
sentence="racecarlevelfield"
print(sentence[4:9])
print(sentence[4:])
print(sentence[-1])
print(sentence[-4:])
print(sentence[5:][0])
print(sentence[5:][:5])
print(sentence[::3])
# Out:
# carle
# carlevelfield
# d
# ield
# a
# arlev
# rervfl

# %%
Sentence="Alice went to the park and saw a beautiful bird singing"
words=Sentence.split(" ")
print(words)
print(words[0])
print(*words[:3])
print(*words[-3:])
print("nr of words",len(words))
# Out:
# ['Alice', 'went', 'to', 'the', 'park', 'and', 'saw', 'a', 'beautiful', 'bird', 'singing']
# Alice
# Alice went to
# beautiful bird singing
# nr of words 11

# %%
pip install wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 20.4 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

wc=WordCloud().generate("rain rain rain brings hope vihm hageln")
img=wc.to_image()
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import urllib.request

text=urllib.request.urlopen("").read().decode("utf-8")
